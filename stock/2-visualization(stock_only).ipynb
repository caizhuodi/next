# %%
import pandas as pd

df = pd.read_csv("./data/^IXIC_history.csv")
# df.head()
print(df)
# Out:
#                             Date          Open          High           Low  \
# 0      1985-01-02 00:00:00-05:00    247.100006    247.100006    245.899994
# 1      1985-01-03 00:00:00-05:00    246.000000    246.699997    246.000000
# 2      1985-01-04 00:00:00-05:00    246.100006    246.100006    245.800003
# 3      1985-01-07 00:00:00-05:00    246.000000    246.199997    245.899994
# 4      1985-01-08 00:00:00-05:00    246.100006    246.399994    246.000000
# ...                          ...           ...           ...           ...
# 10155  2025-04-23 00:00:00-04:00  16880.289062  17029.859375  16642.660156
# 10156  2025-04-24 00:00:00-04:00  16754.759766  17174.349609  16744.970703
# 10157  2025-04-25 00:00:00-04:00  17182.109375  17404.490234  17110.720703
# 10158  2025-04-28 00:00:00-04:00  17390.929688  17467.349609  17128.710938
# 10159  2025-04-29 00:00:00-04:00  17270.759766  17500.419922  17256.199219
#
#               Close       Volume  Dividends  Stock Splits
# ...

# %%
# !pip install mplfinance
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 1.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import mplfinance as mpf  # Please install mplfinance as follows: pip install mplfinance

df = pd.read_csv("./data/^IXIC_history.csv")

df['Date'] = pd.to_datetime(df['Date'], utc=True)

# Set 'Date' column as the index
df.set_index('Date', inplace=True)

df = df.tail(365*1)

# Plot the candlestick chart
mpf.plot(df, type='candlestick', style='charles', title='Stock Price Candlestick Chart', ylabel='Price ($)', figsize=(20, 6), volume=True)
# mpf.plot(df, type='line', style='charles', title='Stock Price Line Chart', ylabel='Price ($)', figsize=(20, 6))
# mpf.plot(df, type='line', style='charles', title='Stock Price Line Chart', ylabel='Price ($)', figsize=(20, 6), volume=True)
